# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
# Out:
# Using TensorFlow backend.

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 47/47 [==============================] - 2s 35ms/step - loss: 2.2112 - accuracy: 0.0851
# Epoch 2/200
# 47/47 [==============================] - 0s 468us/step - loss: 2.1691 - accuracy: 0.1277
# Epoch 3/200
# 47/47 [==============================] - 0s 532us/step - loss: 2.1530 - accuracy: 0.3191
# Epoch 4/200
# 47/47 [==============================] - 0s 489us/step - loss: 1.9857 - accuracy: 0.3191
# Epoch 5/200
# 47/47 [==============================] - 0s 510us/step - loss: 1.8550 - accuracy: 0.4681
# Epoch 6/200
# 47/47 [==============================] - 0s 468us/step - loss: 1.7864 - accuracy: 0.4255
# Epoch 7/200
# 47/47 [==============================] - 0s 532us/step - loss: 1.5858 - accuracy: 0.6596
# Epoch 8/200
# 47/47 [==============================] - 0s 510us/step - loss: 1.6036 - accuracy: 0.5319
# Epoch 9/200
# 47/47 [==============================] - 0s 404us/step - loss: 1.4130 - accuracy: 0.6383
# Epoch 10/200
# 47/47 [==============================] - 0s 447us/step - loss: 1.1710 - accuracy: 0.7447
# Epoch 11/200
# 47/47 [==============================] - 0s 404us/step - loss: 1.0796 - accuracy: 0.7021
# Epoch 12/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.9542 - accuracy: 0.7234
# Epoch 13/200
# 47/47 [==============================] - 0s 447us/step - loss: 1.0804 - accuracy: 0.7021
# Epoch 14/200
# 47/47 [==============================] - 0s 510us/step - loss: 0.8950 - accuracy: 0.8085
# Epoch 15/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.8187 - accuracy: 0.7660
# Epoch 16/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.7575 - accuracy: 0.7660
# Epoch 17/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.7265 - accuracy: 0.8085
# Epoch 18/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.6890 - accuracy: 0.7447
# Epoch 19/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.5501 - accuracy: 0.8085
# Epoch 20/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.6169 - accuracy: 0.8511
# Epoch 21/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.4502 - accuracy: 0.9362
# Epoch 22/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.5951 - accuracy: 0.8936
# Epoch 23/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.3665 - accuracy: 0.9149
# Epoch 24/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.4754 - accuracy: 0.8723
# Epoch 25/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.3561 - accuracy: 0.9362
# Epoch 26/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.2813 - accuracy: 0.9362
# Epoch 27/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.2827 - accuracy: 0.9574
# Epoch 28/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.3204 - accuracy: 0.9149
# Epoch 29/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.2669 - accuracy: 0.8936
# Epoch 30/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.2872 - accuracy: 0.9362
# Epoch 31/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.3198 - accuracy: 0.8936
# Epoch 32/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.3148 - accuracy: 0.9149
# Epoch 33/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.1645 - accuracy: 1.0000
# Epoch 34/200
# 47/47 [==============================] - 0s 489us/step - loss: 0.1648 - accuracy: 0.9787
# Epoch 35/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.2889 - accuracy: 0.8936
# Epoch 36/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.2760 - accuracy: 0.9149
# Epoch 37/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.2021 - accuracy: 0.9787
# Epoch 38/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1326 - accuracy: 0.9787
# Epoch 39/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 40/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.1238 - accuracy: 0.9787
# Epoch 41/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1222 - accuracy: 0.9787
# Epoch 42/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.1406 - accuracy: 0.9787
# Epoch 43/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0792 - accuracy: 1.0000
# Epoch 44/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.1436 - accuracy: 0.9787
# Epoch 45/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.2314 - accuracy: 0.9149
# Epoch 46/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.1827 - accuracy: 0.9787
# Epoch 47/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 48/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0943 - accuracy: 0.9787
# Epoch 49/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0704 - accuracy: 0.9787
# Epoch 50/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.1607 - accuracy: 0.9574
# Epoch 51/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1116 - accuracy: 0.9787
# Epoch 52/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0955 - accuracy: 0.9787
# Epoch 53/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 54/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1200 - accuracy: 0.9787
# Epoch 55/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0816 - accuracy: 0.9574
# Epoch 56/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.2122 - accuracy: 0.9574
# Epoch 57/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0836 - accuracy: 0.9787
# Epoch 58/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.1250 - accuracy: 0.9574
# Epoch 59/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0822 - accuracy: 1.0000
# Epoch 60/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 61/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.1335 - accuracy: 0.9574
# Epoch 62/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0718 - accuracy: 0.9787
# Epoch 63/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 64/200
# 47/47 [==============================] - 0s 702us/step - loss: 0.0855 - accuracy: 0.9787
# Epoch 65/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0797 - accuracy: 0.9574
# Epoch 66/200
# 47/47 [==============================] - 0s 446us/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 67/200
# 47/47 [==============================] - 0s 510us/step - loss: 0.0748 - accuracy: 0.9787
# Epoch 68/200
# 47/47 [==============================] - 0s 532us/step - loss: 0.1260 - accuracy: 0.9787
# Epoch 69/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 70/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.1074 - accuracy: 0.9574
# Epoch 71/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 72/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 73/200
# 47/47 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.80 - 0s 383us/step - loss: 0.0524 - accuracy: 0.9787
# Epoch 74/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0872 - accuracy: 1.0000
# Epoch 75/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0716 - accuracy: 0.9787
# Epoch 76/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0520 - accuracy: 1.0000
# Epoch 77/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1007 - accuracy: 0.9787
# Epoch 78/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0553 - accuracy: 0.9787
# Epoch 79/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 80/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 81/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0547 - accuracy: 0.9787
# Epoch 82/200
# 47/47 [==============================] - 0s 680us/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 83/200
# 47/47 [==============================] - 0s 532us/step - loss: 0.0927 - accuracy: 0.9787
# Epoch 84/200
# 47/47 [==============================] - 0s 447us/step - loss: 0.0522 - accuracy: 0.9787
# Epoch 85/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0619 - accuracy: 0.9787
# Epoch 86/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.1028 - accuracy: 0.9787
# Epoch 87/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 88/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0497 - accuracy: 0.9787
# Epoch 89/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 90/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 91/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0556 - accuracy: 0.9787
# Epoch 92/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 93/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.0568 - accuracy: 0.9787
# Epoch 94/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 95/200
# 47/47 [==============================] - 0s 447us/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 96/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 97/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 98/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0584 - accuracy: 0.9787
# Epoch 99/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 100/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 101/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 102/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 103/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 104/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 105/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 106/200
# 47/47 [==============================] - 0s 766us/step - loss: 0.0533 - accuracy: 0.9787
# Epoch 107/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 108/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0907 - accuracy: 0.9574
# Epoch 109/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 110/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0484 - accuracy: 0.9787
# Epoch 111/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 112/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 113/200
# 47/47 [==============================] - 0s 723us/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 114/200
# 47/47 [==============================] - 0s 447us/step - loss: 0.0488 - accuracy: 0.9787
# Epoch 115/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 116/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 117/200
# 47/47 [==============================] - 0s 489us/step - loss: 0.0878 - accuracy: 0.9787
# Epoch 118/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 119/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 120/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0753 - accuracy: 0.9574
# Epoch 121/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 122/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0634 - accuracy: 0.9787
# Epoch 123/200
# 47/47 [==============================] - 0s 425us/step - loss: 0.0568 - accuracy: 0.9787
# Epoch 124/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 125/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 126/200
# 47/47 [==============================] - 0s 276us/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 127/200
# 47/47 [==============================] - 0s 298us/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 128/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 129/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 130/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 131/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 132/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 133/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 134/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 135/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 136/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 137/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 138/200
# 47/47 [==============================] - 0s 404us/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 139/200
# 47/47 [==============================] - 0s 617us/step - loss: 0.0512 - accuracy: 0.9787
# Epoch 140/200
# 47/47 [==============================] - 0s 574us/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 141/200
# 47/47 [==============================] - 0s 744us/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 142/200
# 47/47 [==============================] - 0s 638us/step - loss: 0.0641 - accuracy: 0.9787
# Epoch 143/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0387 - accuracy: 0.9787
# Epoch 144/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 145/200
# 47/47 [==============================] - 0s 510us/step - loss: 0.0389 - accuracy: 0.9787
# Epoch 146/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0297 - accuracy: 0.9787
# Epoch 147/200
# 47/47 [==============================] - 0s 489us/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 148/200
# 47/47 [==============================] - 0s 532us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 149/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 150/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0543 - accuracy: 0.9787
# Epoch 151/200
# 47/47 [==============================] - 0s 489us/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 152/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 153/200
# 47/47 [==============================] - 0s 489us/step - loss: 0.0739 - accuracy: 0.9574
# Epoch 154/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 155/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0429 - accuracy: 0.9787
# Epoch 156/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 157/200
# 47/47 [==============================] - 0s 553us/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 158/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 159/200
# 47/47 [==============================] - 0s 510us/step - loss: 0.0484 - accuracy: 0.9787
# Epoch 160/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 161/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 162/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 163/200
# 47/47 [==============================] - 0s 574us/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 164/200
# 47/47 [==============================] - 0s 595us/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 165/200
# 47/47 [==============================] - 0s 468us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 166/200
# 47/47 [==============================] - 0s 447us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 167/200
# 47/47 [==============================] - 0s 447us/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 168/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 169/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 170/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 171/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.1206 - accuracy: 0.9574
# Epoch 172/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 173/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 174/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0690 - accuracy: 0.9787
# Epoch 175/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 176/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 177/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 178/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 179/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0419 - accuracy: 0.9787
# Epoch 180/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 181/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 182/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0603 - accuracy: 0.9787
# Epoch 183/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 184/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0425 - accuracy: 0.9787
# Epoch 185/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 186/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 187/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 188/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 189/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 190/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 191/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 192/200
# 47/47 [==============================] - 0s 383us/step - loss: 0.0327 - accuracy: 0.9787
# Epoch 193/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 194/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 195/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 196/200
# 47/47 [==============================] - 0s 361us/step - loss: 0.0737 - accuracy: 0.9574
# Epoch 197/200
# 47/47 [==============================] - 0s 362us/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 198/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0418 - accuracy: 0.9787
# Epoch 199/200
# 47/47 [==============================] - 0s 340us/step - loss: 0.0706 - accuracy: 0.9787
# Epoch 200/200
# 47/47 [==============================] - 0s 319us/step - loss: 0.0044 - accuracy: 1.0000
# model created
