# %%
# General
import pandas as pd
import numpy as np
from dfply import *

# Formatting Text
import re
import string

# Text Analysis
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import LancasterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import spacy
import en_core_web_lg
from spacy import displacy
import textacy

# Plotting
import matplotlib.pyplot as plt
from datetime import date
import networkx as nx

# Sentiment Analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# WordCloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import urllib
import requests
import matplotlib.pyplot as plt

# %%
frame = pd.read_csv("GenConfTalks.csv")
frame.fillna("NA", inplace = True)

# %%
Date = []
for m, y in zip(frame.Month, frame.Year):
    Date.append(date(y, m, 1))
frame['Date'] = Date

# %%
grouped_ = frame.groupby(['Date']).count()
grouped_.insert(0, 'ID', range(100, 100 + len(grouped_)))
frame.set_index(['Date'], inplace=True)

# %%
frame = pd.merge(frame, grouped_[['ID']], right_on='Date', left_index=True)
frame.reset_index(inplace = True)

# %%
stop = list(set(stopwords.words("english"))) + list([x for x in string.punctuation])
printable = set(string.printable)

# %%
def tokening(text): 
    token = word_tokenize(text)
    token = [word.lower() for word in token if word not in stop]
    return token

# %%
frame['Sentence'] = frame['Talk'].apply(lambda x: sent_tokenize(x))
frame['Tokens'] = frame['Talk'].apply(lambda x: tokening(x))
frame.head()
# Out:
#          Date  Year  Month                 Speaker  \
# 0  2019-04-01  2019      4          Ulisses Soares
# 1  2019-04-01  2019      4            Becky Craven
# 2  2019-04-01  2019      4          Brook P. Hales
# 3  2019-04-01  2019      4      Dieter F. Uchtdorf
# 4  2019-04-01  2019      4  W. Christopher Waddell
#
#                                                 Role  \
# 0               Of the Quorum of the Twelve Apostles
# 1  Second Counselor in the Young Women General Pr...
# 2                                     Of the Seventy
# 3               Of the Quorum of the Twelve Apostles
# 4        Second Counselor in the Presiding Bishopric
#
#                                             Title  \
# 0                           How Can I Understand?
# 1                           Careful versus Casual
# 2                               Answers to Prayer
# 3  Missionary Work: Sharing What Is in Your Heart
# 4                                  Just as He Did
#
#                                                 Talk   ID  \
# 0  My dear brothers and sisters, what a great joy...  196
# 1  I once saw a sign in a store window that said,...  196
# 2  An important and comforting doctrine of the go...  196
# 3  Last month the Twelve were invited by our dear...  196
# 4  Approximately 18 months ago, in the fall of 20...  196
#
#                                             Sentence  \
# 0  [My dear brothers and sisters, what a great jo...
# 1  [I once saw a sign in a store window that said...
# 2  [An important and comforting doctrine of the g...
# 3  [Last month the Twelve were invited by our dea...
# 4  [Approximately 18 months ago, in the fall of 2...
#
#                                               Tokens
# 0  [my, dear, brothers, sisters, great, joy, toge...
# 1  [i, saw, sign, store, window, said, happiness,...
# 2  [an, important, comforting, doctrine, gospel, ...
# 3  [last, month, twelve, invited, dear, prophet, ...
# 4  [approximately, 18, months, ago, fall, 2017, 6...

# %% [raw]
# mask = np.array(Image.open(requests.get('http://www.clker.com/cliparts/O/i/x/Y/q/P/yellow-house-hi.png', stream=True).raw))

# %% [raw]
# def generate_wordcloud(words, mask):
#     word_cloud = WordCloud(width = 512, height = 512, background_color='white', stopwords=STOPWORDS, mask=mask, contour_width=1, contour_color='firebrick').generate(words)
#     image_colors = ImageColorGenerator(mask)
#     plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
#     plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation="bilinear")
#     plt.axis('off')
#     plt.tight_layout(pad=0)
#     plt.show()
#
# #Run the following to generate your wordcloud
# generate_wordcloud(y, mask)

# %%
wn = nltk.WordNetLemmatizer()
ps = nltk.PorterStemmer()
def lemm_tokes(texts):
    lems = [wn.lemmatize(text) for text in texts]
    return lems

def stem_tokes(texts):
    lems = [ps.stem(text) for text in texts]
    return lems

# %%
frame['Lem_Tokens'] = frame['Tokens'].apply(lambda x: lemm_tokes(x))
frame['Stem_Tokens'] = frame['Tokens'].apply(lambda x: stem_tokes(x))
frame['POS'] = frame['Tokens'].apply(lambda x: nltk.pos_tag(x))

# %%
ID = []
POS = []
Word = []
for i, item in enumerate(frame['POS']):
    for x in item:
        ID.append(196 - i)
        POS.append(x[1])
        Word.append(x[0])
pos = pd.DataFrame({"ID":ID, "POS":POS, "Word":Word})
pos.head()
# Out:
#     ID   POS      Word
# 0  196  PRP$        my
# 1  196    JJ      dear
# 2  196   NNS  brothers
# 3  196   NNS   sisters
# 4  196    JJ     great

# %%
plt.plot(pos.groupby('POS').count().sort_values('Word', ascending=False),
         color='green', linestyle='dashed', linewidth = 3, 
         marker='o', markerfacecolor='blue', markersize=5)
plt.show()
print(pos.groupby('POS').count().sort_values('Word', ascending=False).head())
# Out:
#           ID     Word
# POS
# NN   1132562  1132562
# JJ    575901   575901
# NNS   377145   377145
# VBP   218619   218619
# RB    208833   208833

# %%
frame.info()
frame.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3839 entries, 0 to 3838
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         3839 non-null   object
#  1   Year         3839 non-null   int64
#  2   Month        3839 non-null   int64
#  3   Speaker      3839 non-null   object
#  4   Role         3839 non-null   object
#  5   Title        3839 non-null   object
#  6   Talk         3839 non-null   object
#  7   ID           3839 non-null   int32
#  8   Sentence     3839 non-null   object
#  9   Tokens       3839 non-null   object
#  10  Lem_Tokens   3839 non-null   object
#  11  Stem_Tokens  3839 non-null   object
#  12  POS          3839 non-null   object
# dtypes: int32(1), int64(2), object(10)
# memory usage: 375.0+ KB
#          Date  Year  Month                 Speaker  \
# 0  2019-04-01  2019      4          Ulisses Soares
# 1  2019-04-01  2019      4            Becky Craven
# 2  2019-04-01  2019      4          Brook P. Hales
# 3  2019-04-01  2019      4      Dieter F. Uchtdorf
# 4  2019-04-01  2019      4  W. Christopher Waddell
#
#                                                 Role  \
# 0               Of the Quorum of the Twelve Apostles
# 1  Second Counselor in the Young Women General Pr...
# 2                                     Of the Seventy
# 3               Of the Quorum of the Twelve Apostles
# 4        Second Counselor in the Presiding Bishopric
#
#                                             Title  \
# 0                           How Can I Understand?
# 1                           Careful versus Casual
# 2                               Answers to Prayer
# 3  Missionary Work: Sharing What Is in Your Heart
# 4                                  Just as He Did
#
#                                                 Talk   ID  \
# 0  My dear brothers and sisters, what a great joy...  196
# 1  I once saw a sign in a store window that said,...  196
# 2  An important and comforting doctrine of the go...  196
# 3  Last month the Twelve were invited by our dear...  196
# 4  Approximately 18 months ago, in the fall of 20...  196
#
#                                             Sentence  \
# 0  [My dear brothers and sisters, what a great jo...
# 1  [I once saw a sign in a store window that said...
# 2  [An important and comforting doctrine of the g...
# 3  [Last month the Twelve were invited by our dea...
# 4  [Approximately 18 months ago, in the fall of 2...
#
#                                               Tokens  \
# 0  [my, dear, brothers, sisters, great, joy, toge...
# 1  [i, saw, sign, store, window, said, happiness,...
# 2  [an, important, comforting, doctrine, gospel, ...
# 3  [last, month, twelve, invited, dear, prophet, ...
# 4  [approximately, 18, months, ago, fall, 2017, 6...
#
#                                           Lem_Tokens  \
# 0  [my, dear, brother, sister, great, joy, togeth...
# 1  [i, saw, sign, store, window, said, happiness,...
# 2  [an, important, comforting, doctrine, gospel, ...
# 3  [last, month, twelve, invited, dear, prophet, ...
# 4  [approximately, 18, month, ago, fall, 2017, 64...
#
#                                          Stem_Tokens  \
# 0  [my, dear, brother, sister, great, joy, togeth...
# 1  [i, saw, sign, store, window, said, happi, 15,...
# 2  [an, import, comfort, doctrin, gospel, jesu, c...
# 3  [last, month, twelv, invit, dear, prophet, pre...
# 4  [approxim, 18, month, ago, fall, 2017, 64-year...
#
#                                                  POS
# 0  [(my, PRP$), (dear, JJ), (brothers, NNS), (sis...
# 1  [(i, NN), (saw, VBD), (sign, NN), (store, NN),...
# 2  [(an, DT), (important, JJ), (comforting, NN), ...
# 3  [(last, JJ), (month, NN), (twelve, VBD), (invi...
# 4  [(approximately, RB), (18, CD), (months, NNS),...

# %%
def sentiment_scores(sentence): 
  
    # Create a SentimentIntensityAnalyzer object. 
    analyzer = SentimentIntensityAnalyzer()
  
    # polarity_scores method of SentimentIntensityAnalyzer 
    # oject gives a sentiment dictionary. 
    # which contains pos, neg, neu, and compound scores. 
    sentiment_dict = analyzer.polarity_scores(sentence) 
      
    #print("Overall sentiment dictionary is : ", sentiment_dict) 
    #print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    #print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    #print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")
    
    # decide sentiment as positive, negative and neutral 
    if sentiment_dict['compound'] >= 0.05 : 
        result = "Positive"
    elif sentiment_dict['compound'] <= - 0.05 : 
        result = "Negative" 
    else : 
        result = "Neutral"
        
    return sentiment_dict['compound']

def scoring(sents):
    scores = []
    for i in range(len(sents)):
        num = sentiment_scores(sents[i])
        scores.append(num)
    x = sum(scores)/len(scores)
    return x

# %% [raw]
# frame["Sentiment"] = frame['Sentence'].apply(lambda x: scoring(x))

# %% [raw]
# x = (frame >>
#     select(X.Date, X.Sentiment) >>
#     group_by(X.Date) >>
#     summarize(Avg = X.Sentiment.mean(), Sum =  X.Sentiment.sum())
# )
#
# fig, ax1 = plt.subplots()
#
# color = 'tab:red'
# ax1.set_xlabel('Date')
# ax1.set_ylabel('Average Sentiment', color=color)
# ax1.plot(x.Date, x.Avg, color=color, linestyle='dashed', linewidth = 3,
#          marker='o', markerfacecolor='blue', markersize=5)
# ax1.tick_params(axis='y', labelcolor=color)
#
# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
#
# color = 'tab:blue'
# ax2.set_ylabel('Sum of Sentiment', color=color)  # we already handled the x-label with ax1
# ax2.plot(x.Date, x.Sum, color=color, linestyle='dashed', linewidth = 3,
#          marker='o', markerfacecolor='blue', markersize=5)
# ax2.tick_params(axis='y', labelcolor=color)
#
# fig.tight_layout()  # otherwise the right y-label is slightly clipped
# plt.show()

# %%
def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)

# %%
def build_similarity_matrix(sentences, stop_words):
    # Create an empty similarity matrix
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
 
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1 == idx2: #ignore if both are same sentences
                continue 
            similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)

    return similarity_matrix


def generate_summary(sentences, top_n=5):
    stop_words = stopwords.words('english')
    summarize_text = []

    # Step 2 - Generate Similary Martix across sentences
    sentence_similarity_martix = build_similarity_matrix(sentences, stop_words)

    # Step 3 - Rank sentences in similarity martix
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_martix)
    scores = nx.pagerank(sentence_similarity_graph)

    # Step 4 - Sort the rank and pick top sentences
    ranked_sentence = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)    

    for i in range(top_n):
      summarize_text.append("".join(ranked_sentence[i][1]))

    # Step 5 - Offcourse, output the summarize texr
    return summarize_text

# %%
index = 77
print(generate_summary(frame['Sentence'][index], 3))
# Out:
# ['Bishops arrived, home and visiting teachers went into action, and Melchizedek and Aaronic Priesthood quorums and Relief Societies organized to take care of both spiritual and temporal needs.',
#  'I choose to think the number only seems large because of a close, caring ward, whose members know when there is a pressing need.',
#  'Hours later I learned that the van belonged to the young couple living across the street from me in Herriman, Eric and Jeana Quigley.']

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import LatentDirichletAllocation

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(frame['Talk'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\pyMain\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Talks'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-ee7d6369649d> in <module>
#       6
#       7 # Fit and transform the processed titles
# ----> 8 count_data = count_vectorizer.fit_transform(frame['Talks'])
#
# ~\Anaconda3\envs\pyMain\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\pyMain\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Talks'

# %%
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below
number_topics = 7
number_words = 10
# Create and fit the LDA model
lda = LatentDirichletAllocation(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=7, n_jobs=-1,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=0)

# %%
# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# church lord president family young time home children know god
#
# Topic #1:
# manifest general proposed favor presidency sustain president counselor members opposed
#
# Topic #2:
# god christ jesus life father lord love world light day
#
# Topic #3:
# lord god faith said children shall life unto man jesus
#
# Topic #4:
# god lord christ jesus unto shall book said ye father
#
# Topic #5:
# god priesthood lord jesus holy christ man things power unto
#
# Topic #6:
# women things spiritual leave little young world self right immovable

# %%
# %%time
from pyLDAvis import sklearn as sklearn_lda
import pickle 
import pyLDAvis
from os import path

LDAvis_data_filepath = path.join('./ldavis_prepared')
# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
LDAvis_prepared = sklearn_lda.prepare(lda, count_data, count_vectorizer)
print(LDAvis_prepared)

if 1 == 0:
    with open(LDAvis_data_filepath, 'w') as f:
            pickle.dump(LDAvis_prepared, f)

    # load the pre-prepared pyLDAvis data from disk
    with open(LDAvis_data_filepath) as f:
        LDAvis_prepared = pickle.load(f)
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.073673 -0.037793       1        1  45.059720
# 2     -0.113782 -0.005710       2        1  18.309613
# 3     -0.065721  0.010545       3        1  14.418655
# 4     -0.097155 -0.025593       4        1  13.349649
# 5     -0.064286  0.005357       5        1   6.481948
# 6      0.146934  0.158363       6        1   1.198235
# 1      0.267683 -0.105169       7        1   1.182180, topic_info=             Term         Freq        Total Category  logprob  loglift
# 7555          god  2927.000000  2927.000000  Default  30.0000  30.0000
# 12937  priesthood   932.000000   932.000000  Default  29.0000  29.0000
# 12880   president  1233.000000  1233.000000  Default  28.0000  28.0000
# 10617     members   691.000000   691.000000  Default  27.0000  27.0000
# 18704       young  1069.000000  1069.000000  Default  26.0000  26.0000
# ...           ...          ...          ...      ...      ...      ...
# 4444        david    10.116603   130.485054   Topic7  -5.8656   1.8807
# 18477        wish     9.949747   117.643985   Topic7  -5.8822   1.9677
# 16632      temple    10.777219   415.843609   Topic7  -5.8023   0.7849
# 18704       young    10.692960  1069.509211   Topic7  -5.8102  -0.1676
# 15027     service     9.964561   539.369663   Topic7  -5.8807   0.4464
#
# [596 rows x 6 columns], token_table=       Topic      Freq     Term
# term
# 72         5  0.950201      157
# 527        1  0.655283  aaronic
# 527        3  0.029341  aaronic
# 527        5  0.312971  aaronic
# 550        4  0.919559  abinadi
# ...      ...       ...      ...
# 18704      3  0.040205    young
# 18704      4  0.040205    young
# 18704      5  0.084151    young
# 18704      6  0.011220    young
# 18704      7  0.010285    young
#
# [1383 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 4, 5, 6, 7, 2])
# Wall time: 15.8 s

# %%
pyLDAvis.save_html(LDAvis_prepared, './ldavis_prepared_'+ str(number_topics) +'.html')

# %% [markdown]
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************
# **********************************************************************************************************

# %%
nlp = en_core_web_lg.load()

# %%
text = "".join(frame['Sentence'][6])
doc = nlp(text)

# %%
def summary(doc):
    summary = ''
    ent_list = []
    for e in doc.ents:
        if e.label_ == "PERSON":
            ent_list.append(str(e).lower().strip())
    ent_list = list( dict.fromkeys(ent_list) )
    for ent in ent_list:
        sentences = textacy.extract.semistructured_statements(doc, ent)
        for statement in sentences:
            subject, verb, fact = statement
            if len(fact) > 1:
                print(ent)
                print(" - Fact: ", fact)
    return summary

# %%
summary(doc)
# Out:
# hinckley
#  - Fact:  the prophet and that the membership of the Church will be praying for me and my family
# faith
#  - Fact:  a great comfort to Mary and me
# ''

# %%
def print_ents(doc):
    sentence_spans = list(doc.sents)
    displacy.render(sentence_spans, style="ent")
    
print_ents(doc)
# Out:
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# C:\Users\calla\Anaconda3\envs\pyMain\lib\runpy.py:193: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   "__main__", mod_spec)
# <div class="entities" style="line-height: 2.5; direction: ltr">Dear brothers and sisters, I join with you in expressing my love and sustaining support to President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eyring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and his family.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hinckley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  extended this call to serve in the Quorum of the Twelve
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">I cannot possibly articulate the kaleidoscope of feelings I have experienced since then.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">There have been
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sleepless nights
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  and much prayer.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">My spirits have been buoyed, however, by the knowledge that President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hinckley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the prophet and that the membership of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Church
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will be praying for me and my family.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">To say that I feel deeply inadequate would be an understatement.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">When I was called as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a General Authority
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April of 1996
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I also felt unequal to the calling.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Elder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Neal A. Maxwell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reassured me then that the most important qualification for all of us serving in the kingdom is to be comfortable in bearing witness of the divinity of the Savior.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A peace came over me at that time and has stayed with me since because I love the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Savior
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and have had spiritual experiences that allow me to testify of Him.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">I rejoice in the opportunity to bear witness of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jesus Christ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in all the world (see ), notwithstanding my inadequacies.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In , we read: Behold, this is the promise of the Lord unto you,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     O ye my servants
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Wherefore, be of good cheer, and do not fear, for I the Lord am with you, and will stand by you; and ye shall bear record of me, even
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jesus Christ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , that I am
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Son of the living
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  God, that I was, that I am, and that I am to come.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">I seek the companionship of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Holy Ghost
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  as I speak with you this Sabbath morning.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The overwhelming feeling that I have in receiving this call is that we must live by faith and not by fear.</div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;"

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.decomposition import NMF

vectorizer = TfidfVectorizer(stop_words='english',analyzer='word', max_features=5000)
x_counts = vectorizer.fit_transform(frame["Talk"]);

transformer = TfidfTransformer(smooth_idf=False);
x_tfidf = transformer.fit_transform(x_counts);

xtfidf_norm = normalize(x_tfidf, norm='l1', axis=1)

num_topics = 6

#obtain a NMF model.
model = NMF(n_components=num_topics, init='nndsvd');
#fit the model
model.fit(xtfidf_norm)

def get_nmf_topics(model, n_top_words):
    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(num_topics):
        
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-20 - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
dframe = get_nmf_topics(model, 20)

# %%
dframe
# Out:
#      Topic # 01 Topic # 02    Topic # 03   Topic # 04    Topic # 05  \
# 0      proposed        god      auditing     emeritus    priesthood
# 1         favor       lord    department     branches        relief
# 2      manifest      shall  expenditures      seventy       society
# 3       opposed         ye        audits   statistics         women
# 4       sustain     christ   departments           31        family
# 5     counselor       unto         audit        widow         young
# 6     seventies      jesus         funds     december       welfare
# 7   constituted       book       budgets        wards        church
# 8          sign     father    accounting       issued          home
# 9   authorities      ghost    procedures       status        bishop
# 10      general       holy      policies    counselor    missionary
# 11      release     mormon    operations   presidency  missionaries
# 12         vote        thy        assets      reports     president
# 13      seventy      light    accordance      general        temple
# 14       quorum       thou    controlled        elder          ward
# 15      russell       life       systems  information       sisters
# 16   presidency      earth      approved        prior       mission
# 17     uplifted     savior   independent   membership        quorum
# 18       robert     joseph     financial       sister        mother
# 19     contrary        son        budget       member          love
#
#      Topic # 06
# 0            31
# 1        issued
# 2      december
# 3     operation
# 4        mexico
# 5        status
# 6     dedicated
# 7       arizona
# 8     argentina
# 9        report
# 10    regarding
# 11         peru
# 12      florida
# 13         utah
# 14       growth
# 15   presidency
# 16  information
# 17    following
# 18       brazil
# 19      service
