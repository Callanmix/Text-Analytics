# %%
import pandas as pd
import re

# %%
text = pd.read_excel("AAD-01_Qualtrics Export.xlsx", sheet_name="IT_Text")
num = pd.read_excel("AAD-01_Qualtrics Export.xlsx", sheet_name="IT_Num")

# %%
for i, col in enumerate(num.columns):
    print(i, " ", col)
# Out:
# 0   StartDate
# 1   EndDate
# 2   Status
# 3   IPAddress
# 4   Progress
# 5   Duration (in seconds)
# 6   Finished
# 7   RecordedDate
# 8   ResponseId
# 9   RecipientLastName
# 10   RecipientFirstName
# 11   RecipientEmail
# 12   ExternalReference
# 13   LocationLatitude
# 14   LocationLongitude
# 15   DistributionChannel
# 16   UserLanguage
# 17   Persona
# 18   Persona_3_TEXT
# 19   IAM_Involvement
# 20   IAM_Providers
# 21   IAM_Providers_7_TEXT
# 22   IAM_Capabilities
# 23   IAM_Capabilities_7_TEXT
# 24   MRI
# 25   AAD_SKU
# 26   MS_Relationship
# 27   MS_Partner
# 28   MS_Services
# 29   MS_Services_9_TEXT
# 30   OSAT_x1
# 31   OSAT_x2
# 32   OSAT_x3
# 33   OSAT_x4
# 34   OSAT_x5
# 35   OSAT_x6
# 36   OSAT_x7
# 37   OSAT_x7_TEXT
# 38   OSAT_x8
# 39   Renew_x1
# 40   Renew_x2
# 41   Renew_x3
# 42   Renew_x4
# 43   Renew_x5
# 44   Renew_x6
# 45   Renew_x7
# 46   Renew_x7_TEXT
# 47   Renew_x8
# 48   Increase_Decrease_x1
# 49   Increase_Decrease_x2
# 50   Increase_Decrease_x3
# ...

# %%
columns = []
for i in num.columns[30:320]:
    columns.append(i)

# %%
for i in range(len(columns)):
    num.drop(columns[i], inplace=True, axis=1)

# %%
num
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"America/De...
# 2                                  2017-08-29 17:37:04
# 3                                  2017-08-29 17:55:51
# 4                                  2017-08-29 18:11:41
# ..                                                 ...
# 149                                2017-09-28 17:50:59
# 150                                2017-09-28 18:39:49
# 151                                2017-09-28 21:32:45
# 152                                2017-09-29 01:33:31
# 153                                2017-09-29 01:22:30
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# ...
